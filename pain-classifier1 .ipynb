# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/painmonit-dataset/painmonit_dua.pdf
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_49-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_40-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_11-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_41-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_42-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_03-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_12-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_30-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_13-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_25-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_09-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_26-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_52-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_32-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_38-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_23-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_05-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_21-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_43-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_19-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_15-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_10-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_35-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_02-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_17-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_16-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_33-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_18-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_48-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_24-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_04-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_28-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_39-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_01-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_31-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_27-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_06-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_07-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_44-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_50-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_29-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_45-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_22-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_08-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_37-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_20-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_34-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_51-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_36-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_46-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_14-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data/S_47-synchronised-data.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P44_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P44_1/P44_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P44_1/P44_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P44_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P14_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P14_2/P14_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P14_2/P14_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P14_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P17_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P17_2/P17_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P17_2/P17_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P17_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P30_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P30_2/P30_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P30_2/P30_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P30_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P21_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P21_1/P21_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P21_1/P21_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P21_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P07_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P07_1/P07_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P07_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P07_1/P07_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P05_2/P05_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P05_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P05_2/P05_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P05_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P35_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P35_2/P35_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P35_2/P35_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P35_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P12_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P12_2/P12_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P12_2/P12_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P12_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P22_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P22_2/P22_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P22_2/P22_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P22_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P26_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P26_1/P26_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P26_1/P26_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P26_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P01_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P01_1/P01_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P01_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P01_1/P01_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P27_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P27_2/P27_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P27_2/P27_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P27_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P39_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P39_1/P39_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P39_1/P39_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P39_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P45_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P45_1/P45_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P45_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P45_1/P45_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P48_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P48_1/P48_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P48_1/P48_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P48_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P18_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P18_2/P18_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P18_2/P18_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P18_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P13_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P13_2/P13_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P13_2/P13_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P13_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P10_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P10_1/P10_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P10_1/P10_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P10_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P23_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P23_2/P23_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P23_2/P23_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P23_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P42_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P42_2/P42_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P42_2/P42_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P42_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P32_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P32_2/P32_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P32_2/P32_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P32_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P24_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P24_1/P24_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P24_1/P24_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P24_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P46_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P46_2/P46_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P46_2/P46_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P46_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P40_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P40_2/P40_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P40_2/P40_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P40_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P08_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P08_1/P08_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P08_1/P08_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P08_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P38_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P38_2/P38_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P38_2/P38_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P38_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P23_1/P23_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P23_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P23_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P23_1/P23_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P09_2/P09_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P09_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P09_2/P09_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P09_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P35_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P35_1/P35_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P35_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P35_1/P35_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P34_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P34_1/P34_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P34_1/P34_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P34_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P29_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P29_2/P29_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P29_2/P29_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P29_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P22_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P22_1/P22_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P22_1/P22_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P22_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P33_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P33_1/P33_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P33_1/P33_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P33_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P16_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P16_2/P16_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P16_2/P16_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P16_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P15_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P15_1/P15_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P15_1/P15_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P15_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P16_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P16_1/P16_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P16_1/P16_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P16_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P04_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P04_2/P04_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P04_2/P04_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P04_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P19_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P19_1/P19_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P19_1/P19_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P19_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P20_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P20_2/P20_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P20_2/P20_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P20_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P34_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P34_2/P34_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P34_2/P34_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P34_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P37_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P37_1/P37_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P37_1/P37_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P37_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P46_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P46_1/P46_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P46_1/P46_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P46_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P41_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P41_2/P41_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P41_2/P41_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P41_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P06_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P06_2/P06_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P06_2/P06_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P06_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P07_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P07_2/P07_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P07_2/P07_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P07_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P25_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P25_2/P25_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P25_2/P25_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P25_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P17_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P17_1/P17_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P17_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P17_1/P17_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P19_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P19_2/P19_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P19_2/P19_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P19_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P02_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P02_2/P02_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P02_2/P02_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P02_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P37_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P37_2/P37_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P37_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P37_2/P37_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P47_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P47_1/P47_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P47_1/P47_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P47_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P44_2/P44_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P44_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P44_2/P44_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P44_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P49_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P49_1/P49_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P49_1/P49_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P49_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P31_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P31_1/P31_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P31_1/P31_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P31_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P11_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P11_1/P11_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P11_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P11_1/P11_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P02_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P02_1/P02_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P02_1/P02_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P02_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P32_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P32_1/P32_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P32_1/P32_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P32_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P28_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P28_1/P28_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P28_1/P28_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P28_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P04_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P04_1/P04_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P04_1/P04_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P04_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P06_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P06_1/P06_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P06_1/P06_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P06_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P45_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P45_2/P45_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P45_2/P45_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P45_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P26_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P26_2/P26_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P26_2/P26_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P26_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P05_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P05_1/P05_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P05_1/P05_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P05_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P40_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P40_1/P40_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P40_1/P40_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P40_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P18_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P18_1/P18_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P18_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P18_1/P18_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P43_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P43_2/P43_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P43_2/P43_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P43_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P27_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P27_1/P27_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P27_1/P27_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P27_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P09_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P09_1/P09_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P09_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P09_1/P09_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P49_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P49_2/P49_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P49_2/P49_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P49_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P29_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P29_1/P29_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P29_1/P29_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P29_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P03_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P03_1/P03_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P03_1/P03_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P03_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P25_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P25_1/P25_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P25_1/P25_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P25_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P47_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P47_2/P47_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P47_2/P47_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P47_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P20_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P20_1/P20_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P20_1/P20_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P20_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P21_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P21_2/P21_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P21_2/P21_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P21_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P36_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P36_1/P36_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P36_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P36_1/P36_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P30_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P30_1/P30_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P30_1/P30_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P30_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P42_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P42_1/P42_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P42_1/P42_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P42_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P08_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P08_2/P08_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P08_2/P08_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P08_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P36_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P36_2/P36_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P36_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P36_2/P36_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P12_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P12_1/P12_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P12_1/P12_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P12_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P24_2/P24_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P24_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P24_2/P24_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P24_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P28_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P28_2/P28_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P28_2/P28_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P28_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P39_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P39_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P39_2/P39_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P39_2/P39_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P13_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P13_1/P13_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P13_1/P13_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P13_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P01_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P01_2/P01_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P01_2/P01_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P01_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P10_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P10_2/P10_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P10_2/P10_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P10_2/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P14_1/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P14_1/P14_1.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P14_1/P14_1_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P14_1/severePainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P03_2/noPainThreshold.txt
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P03_2/P03_2_runUp.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P03_2/P03_2.csv
# /kaggle/input/painmonit-dataset/PMCD/PMPDB/raw-data/P03_2/severePainThreshold.txt

# %% [markdown]
# ## Load & Concatenate All Subject CSVs

# %%
# Path to your PMHDB dataset folder (update accordingly)
data_path = "/kaggle/input/painmonit-dataset/PMED/PMHDB/raw-data"

all_data = []

for i in range(1, 30):  # 01 to 52
    file_name = f"S_{i:02d}-synchronised-data.csv"
    file_path = os.path.join(data_path, file_name)
    
    # Read CSV with semicolon delimiter
    df = pd.read_csv(file_path, delimiter=";")
    
    # Add subject ID column
    df["Subject_ID"] = i
    
    all_data.append(df)

# Concatenate all subjects
pmhdb_df = pd.concat(all_data, ignore_index=True)

print("Shape of concatenated dataset:", pmhdb_df.shape)
print("Columns:", pmhdb_df.columns.tolist())
pmhdb_df.head()
# Out:
# /tmp/ipykernel_115/4186084227.py:11: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path, delimiter=";")
# Shape of concatenated dataset: (10442080, 14)
# Columns: ['Seconds', 'Bvp', 'Eda_E4', 'Tmp', 'Ibi', 'Hr', 'Resp', 'Eda_RB', 'Ecg', 'Emg', 'Heater [C]', 'COVAS', 'Heater_cleaned', 'Subject_ID']
#   Seconds       Bvp             Eda_E4                 Tmp  \
# 0     0,0  19,85744  5,449181107142857   35,18569230769231
# 1   0,004  19,57863  5,449066803571428              35,186
# 2   0,008  19,29982  5,448952499999999   35,18630769230769
# 3   0,012  19,02101  5,448838196428571  35,186615384615386
# 4   0,016  18,11296  5,448723892857142   35,18692307692307
#
#                   Ibi                 Hr                 Resp  \
# 0  0,7165260688888889   83,7484398888889       -1,23291015625
# 1  0,7166996866666666  83,72736066666667    -1,17034912109375
# 2  0,7168733044444445  83,70628144444446  -1,2090047200520833
# 3  0,7170469222222222  83,68520222222224    -1,24664306640625
# 4          0,71722054          83,664123    -1,22222900390625
#
#                Eda_RB                   Ecg                  Emg  \
# 0   11,74850463867185  -0,05706024169921875   -0,001373291015625
# 1   11,73439025878905    -0,049530029296875  0,00212860107421875
# 2  11,741638183593734   -0,0505218505859375   0,0019989013671875
# 3    11,7458343505859    -0,049163818359375  -0,0042572021484375
# 4    11,7366790771484   -0,0476531982421875  -0,0070037841796875
#
#            Heater [C] COVAS Heater_cleaned  Subject_ID
# 0               32,01   0,0           32,0           1
# 1  32,023999999999994   0,0           32,0           1
# 2              32,038   0,0           32,0           1
# 3   32,05199999999999   0,0           32,0           1
# 4  32,065999999999995   0,0           32,0           1

# %%
pmhdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10442080 entries, 0 to 10442079
# Data columns (total 14 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Seconds         object
#  1   Bvp             object
#  2   Eda_E4          object
#  3   Tmp             object
#  4   Ibi             object
#  5   Hr              object
#  6   Resp            object
#  7   Eda_RB          object
#  8   Ecg             object
#  9   Emg             object
#  10  Heater [C]      object
#  11  COVAS           object
#  12  Heater_cleaned  object
#  13  Subject_ID      int64
# dtypes: int64(1), object(13)
# memory usage: 1.1+ GB

# %% [markdown]
# ## Data Cleaning

# %%
# =========================
# Cell 2: Robust Data Cleaning
# =========================

import pandas as pd
import numpy as np

# List of features we know should be numeric
numeric_cols = [
    "Seconds", "Bvp", "Eda_E4", "Tmp", "Ibi", "Hr", "Resp",
    "Eda_RB", "Ecg", "Emg", "Heater [C]", "COVAS", "Heater_cleaned"
]

# Convert Subject_ID to string
pmhdb_df["Subject_ID"] = pmhdb_df["Subject_ID"].astype(str)

# Function to safely convert strings to float
def safe_float(x):
    try:
        return float(str(x).replace(',', '.').strip())
    except:
        return np.nan

# Apply conversion
for col in numeric_cols:
    pmhdb_df[col] = pmhdb_df[col].apply(safe_float)

# Fill missing values forward/backward
pmhdb_df[numeric_cols] = pmhdb_df[numeric_cols].fillna(method='ffill').fillna(method='bfill')

# Drop rows where target is still missing
pmhdb_df = pmhdb_df.dropna(subset=["COVAS"])

# Check
print("After cleaning, dataset shape:", pmhdb_df.shape)
print("Column types:")
print(pmhdb_df.dtypes)
print("\nSample:")
print(pmhdb_df.head())
# Out:
# /tmp/ipykernel_115/56689320.py:29: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pmhdb_df[numeric_cols] = pmhdb_df[numeric_cols].fillna(method='ffill').fillna(method='bfill')
# After cleaning, dataset shape: (10442080, 14)
# Column types:
# Seconds           float64
# Bvp               float64
# Eda_E4            float64
# Tmp               float64
# Ibi               float64
# Hr                float64
# Resp              float64
# Eda_RB            float64
# Ecg               float64
# Emg               float64
# Heater [C]        float64
# COVAS             float64
# Heater_cleaned    float64
# Subject_ID         object
# dtype: object
#
# Sample:
#    Seconds       Bvp    Eda_E4        Tmp       Ibi         Hr      Resp  \
# 0    0.000  19.85744  5.449181  35.185692  0.716526  83.748440 -1.232910
# 1    0.004  19.57863  5.449067  35.186000  0.716700  83.727361 -1.170349
# 2    0.008  19.29982  5.448952  35.186308  0.716873  83.706281 -1.209005
# 3    0.012  19.02101  5.448838  35.186615  0.717047  83.685202 -1.246643
# 4    0.016  18.11296  5.448724  35.186923  0.717221  83.664123 -1.222229
#
#       Eda_RB       Ecg       Emg  Heater [C]  COVAS  Heater_cleaned Subject_ID
# 0  11.748505 -0.057060 -0.001373      32.010    0.0            32.0          1
# 1  11.734390 -0.049530  0.002129      32.024    0.0            32.0          1
# 2  11.741638 -0.050522  0.001999      32.038    0.0            32.0          1
# 3  11.745834 -0.049164 -0.004257      32.052    0.0            32.0          1
# 4  11.736679 -0.047653 -0.007004      32.066    0.0            32.0          1

# %% [markdown]
# ## LOSO

# %%
from sklearn.model_selection import LeaveOneGroupOut

# Features & target
X = pmhdb_df.drop(columns=["COVAS", "Subject_ID"])  # predictors only
y = pmhdb_df["COVAS"]                               # pain score (target)
groups = pmhdb_df["Subject_ID"]                     # subject IDs for LOSO

# LOSO splitter
logo = LeaveOneGroupOut()

print("Total folds (subjects):", logo.get_n_splits(X, y, groups))

# Loop through folds (we’ll plug in model training later)
for fold, (train_idx, test_idx) in enumerate(logo.split(X, y, groups), start=1):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    test_subject = groups.iloc[test_idx].iloc[0]  # which subject is test
    
    print(f"\n--- Fold {fold}/{logo.get_n_splits(X, y, groups)} ---")
    print(f"Train size: {X_train.shape}, Test size: {X_test.shape}, Test subject: {test_subject}")
    
    # Placeholder: later we’ll train XGBoost here
    # model.fit(X_train, y_train)
    # preds = model.predict(X_test)
# Out:
# Total folds (subjects): 29
#
# --- Fold 1/29 ---
# Train size: (10079179, 12), Test size: (362901, 12), Test subject: 1
#
# --- Fold 2/29 ---
# Train size: (10082963, 12), Test size: (359117, 12), Test subject: 10
#
# --- Fold 3/29 ---
# Train size: (10077190, 12), Test size: (364890, 12), Test subject: 11
#
# --- Fold 4/29 ---
# Train size: (10071530, 12), Test size: (370550, 12), Test subject: 12
#
# --- Fold 5/29 ---
# Train size: (10083516, 12), Test size: (358564, 12), Test subject: 13
#
# --- Fold 6/29 ---
# Train size: (10080144, 12), Test size: (361936, 12), Test subject: 14
#
# --- Fold 7/29 ---
# Train size: (10086228, 12), Test size: (355852, 12), Test subject: 15
#
# --- Fold 8/29 ---
# Train size: (10090703, 12), Test size: (351377, 12), Test subject: 16
#
# --- Fold 9/29 ---
# Train size: (10083993, 12), Test size: (358087, 12), Test subject: 17
#
# --- Fold 10/29 ---
# Train size: (10080959, 12), Test size: (361121, 12), Test subject: 18
#
# --- Fold 11/29 ---
# Train size: (10083425, 12), Test size: (358655, 12), Test subject: 19
#
# --- Fold 12/29 ---
# Train size: (10079934, 12), Test size: (362146, 12), Test subject: 2
#
# --- Fold 13/29 ---
# Train size: (10079763, 12), Test size: (362317, 12), Test subject: 20
#
# --- Fold 14/29 ---
# Train size: (10085158, 12), Test size: (356922, 12), Test subject: 21
#
# --- Fold 15/29 ---
# Train size: (10087699, 12), Test size: (354381, 12), Test subject: 22
#
# --- Fold 16/29 ---
# Train size: (10078694, 12), Test size: (363386, 12), Test subject: 23
#
# --- Fold 17/29 ---
# Train size: (10083329, 12), Test size: (358751, 12), Test subject: 24
#
# --- Fold 18/29 ---
# Train size: (10081554, 12), Test size: (360526, 12), Test subject: 25
#
# --- Fold 19/29 ---
# Train size: (10079763, 12), Test size: (362317, 12), Test subject: 26
#
# --- Fold 20/29 ---
# Train size: (10076552, 12), Test size: (365528, 12), Test subject: 27
#
# --- Fold 21/29 ---
# Train size: (10071989, 12), Test size: (370091, 12), Test subject: 28
#
# --- Fold 22/29 ---
# Train size: (10081559, 12), Test size: (360521, 12), Test subject: 29
#
# --- Fold 23/29 ---
# Train size: (10089748, 12), Test size: (352332, 12), Test subject: 3
#
# --- Fold 24/29 ---
# Train size: (10088770, 12), Test size: (353310, 12), Test subject: 4
#
# --- Fold 25/29 ---
# Train size: (10089228, 12), Test size: (352852, 12), Test subject: 5
#
# --- Fold 26/29 ---
# Train size: (10083308, 12), Test size: (358772, 12), Test subject: 6
#
# --- Fold 27/29 ---
# Train size: (10088429, 12), Test size: (353651, 12), Test subject: 7
#
# --- Fold 28/29 ---
# Train size: (10079039, 12), Test size: (363041, 12), Test subject: 8
#
# --- Fold 29/29 ---
# Train size: (10073894, 12), Test size: (368186, 12), Test subject: 9

# %%
# Ensure numeric and drop NaN/inf
pmhdb_df["COVAS"] = pd.to_numeric(pmhdb_df["COVAS"], errors="coerce")
pmhdb_df = pmhdb_df.replace(np.inf, np.nan)
pmhdb_df = pmhdb_df.replace(-np.inf, np.nan)
pmhdb_df = pmhdb_df.dropna(subset=["COVAS"])  # drop rows where target is NaN

print("After cleaning, dataset shape:", pmhdb_df.shape)
print("COVAS min:", pmhdb_df["COVAS"].min(), "max:", pmhdb_df["COVAS"].max())
# Out:
# After cleaning, dataset shape: (10442080, 14)
# COVAS min: 0.0 max: 100.00000000000001

# %%
# --- Fix column names for XGBoost compatibility ---
pmhdb_df.columns = (
    pmhdb_df.columns
    .str.replace(r"\[|\]|<|>", "", regex=True)  # remove forbidden characters
    .str.replace(" ", "_")                      # replace spaces with underscores
)

print("Cleaned column names:", pmhdb_df.columns.tolist())
# Out:
# Cleaned column names: ['Seconds', 'Bvp', 'Eda_E4', 'Tmp', 'Ibi', 'Hr', 'Resp', 'Eda_RB', 'Ecg', 'Emg', 'Heater_C', 'COVAS', 'Heater_cleaned', 'Subject_ID']

# %%
import re

# Sanitize all column names in the master dataframe
pmhdb_df = pmhdb_df.rename(columns=lambda x: re.sub(r"[^A-Za-z0-9_]+", "_", str(x)))

# If you already extracted feature columns, re-pull them
feature_cols = [col for col in pmhdb_df.columns if col != "subject" and col != "target"]

print("Sanitized feature columns:")
print(feature_cols[:20])  # show first 20 just to check
# Out:
# Sanitized feature columns:
# ['Seconds', 'Bvp', 'Eda_E4', 'Tmp', 'Ibi', 'Hr', 'Resp', 'Eda_RB', 'Ecg', 'Emg', 'Heater_C', 'COVAS', 'Heater_cleaned', 'Subject_ID']

# %%
X_train = X_train.rename(columns=lambda x: re.sub(r"[^A-Za-z0-9_]+", "_", str(x)))
X_test  = X_test.rename(columns=lambda x: re.sub(r"[^A-Za-z0-9_]+", "_", str(x)))

# %% [markdown]
# ## XGBoost Regressor

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
import numpy as np

# hyperparams to try
xgb_params = {
    "n_estimators": 2000,
    "learning_rate": 0.03,
    "max_depth": 4,
    "min_child_weight": 5,
    "subsample": 0.75,
    "colsample_bytree": 0.7,
    "reg_alpha": 0.1,
    "reg_lambda": 3.0,
    "gamma": 0.1,
    "random_state": 42,
    "verbosity": 0,
    # "booster": "dart"   # uncomment to try dropout-like behavior
}

# inside LOSO loop (for each fold)
# X_train, y_train, X_test, y_test already defined
X_tr_sub, X_val_sub, y_tr_sub, y_val_sub = train_test_split(
    X_train, y_train, test_size=0.1, random_state=42
)

model = XGBRegressor(**xgb_params)

# fit with eval_set for early stopping
model.fit(
    X_tr_sub, y_tr_sub,
    eval_set=[(X_val_sub, y_val_sub)],
    early_stopping_rounds=50,
    verbose=50
)

# predict and clip between 0 and 100
preds = model.predict(X_test)
preds = np.clip(preds, 0.0, 100.0)
# Out:
# /usr/local/lib/python3.11/dist-packages/xgboost/sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-rmse:19.30065
# [50]	validation_0-rmse:15.45597
# [100]	validation_0-rmse:14.50666
# [150]	validation_0-rmse:14.08591
# [200]	validation_0-rmse:13.75990
# [250]	validation_0-rmse:13.49684
# [300]	validation_0-rmse:13.31126
# [350]	validation_0-rmse:13.14015
# [400]	validation_0-rmse:12.97873
# [450]	validation_0-rmse:12.83784
# [500]	validation_0-rmse:12.67972
# [550]	validation_0-rmse:12.56288
# [600]	validation_0-rmse:12.44404
# [650]	validation_0-rmse:12.31015
# [700]	validation_0-rmse:12.21863
# [750]	validation_0-rmse:12.13009
# [800]	validation_0-rmse:12.06202
# [850]	validation_0-rmse:11.97672
# [900]	validation_0-rmse:11.89482
# [950]	validation_0-rmse:11.82091
# [1000]	validation_0-rmse:11.74916
# [1050]	validation_0-rmse:11.68092
# [1100]	validation_0-rmse:11.61785
# [1150]	validation_0-rmse:11.55818
# [1200]	validation_0-rmse:11.49079
# [1250]	validation_0-rmse:11.43415
# [1300]	validation_0-rmse:11.37148
# [1350]	validation_0-rmse:11.31126
# [1400]	validation_0-rmse:11.24704
# [1450]	validation_0-rmse:11.18685
# [1500]	validation_0-rmse:11.12828
# [1550]	validation_0-rmse:11.06998
# [1600]	validation_0-rmse:11.01635
# [1650]	validation_0-rmse:10.95603
# [1700]	validation_0-rmse:10.91074
# [1750]	validation_0-rmse:10.87211
# [1800]	validation_0-rmse:10.82522
# [1850]	validation_0-rmse:10.77959
# [1900]	validation_0-rmse:10.74277
# [1950]	validation_0-rmse:10.70333
# [1999]	validation_0-rmse:10.66417

# %%
import numpy as np
from sklearn.metrics import mean_squared_error

# assuming y_train_all are concatenation of all training y across folds or global train
mean_pred = np.mean(y_train)  # or compute per-fold
rmse_baseline = np.sqrt(mean_squared_error(y_test, np.full_like(y_test, mean_pred)))
print("Baseline (mean) RMSE:", rmse_baseline)
# Out:
# Baseline (mean) RMSE: 25.851085860017545

# %%
import joblib

# Save the trained model
joblib.dump(model, "/kaggle/working/xgb_model.pkl")
# Out:
# ['/kaggle/working/xgb_model.pkl']

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_115/1904784326.py in <cell line: 0>()
#      11 target = "Target"   # <-- replace with your actual target column
#      12
# ---> 13 X = df[features].values
#      14 y = df[target].values
#      15
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Wind Speed', 'Ozone', 'Relative Humidity', 'Benzene', 'CO', 'PM2.5',\n       'NOx'],\n      dtype='object')] are in the [columns]"
